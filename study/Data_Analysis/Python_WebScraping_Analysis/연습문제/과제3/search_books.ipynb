# %%
# 1 : 검색어로 찾은 책 목록을 json 파일로 저장하기
import requests
import json
import os
from dotenv import load_dotenv

# .env 파일에서 환경 변수 로드
load_dotenv()

client_id = os.getenv("NAVER_CLIENT_ID")
client_secret = os.getenv("NAVER_CLIENT_SECRET")

headers = {
    'X-Naver-Client-Id': client_id,
    'X-Naver-Client-Secret': client_secret,
}

def search_books_no_try_except(query):
    payload = {
        'query': query,
        'display': 50,
        'sort': 'sim'
    }
    url = 'https://openapi.naver.com/v1/search/book.json'

    # 1) API 요청
    res = requests.get(url, params=payload, headers=headers)
    
    # 2) HTTP 상태 코드 확인 (raise_for_status() 대신 수동으로 확인)
    #    200 OK가 아니면 여기서 오류가 발생
    if res.status_code != 200:
        print(f"API 요청 실패: 상태 코드 {res.status_code}, 응답: {res.text}")
        # 오류 처리 없이 진행하면 아래 res.json()에서 에러 날 수 있음
        return [] 
        
    # 3) JSON 파싱
    #    응답이 JSON 형식이 아니거나 'items' 키가 없으면 여기서 오류 발생
    items_data = res.json()['items'] 
    return items_data

def save_to_json_file(data, filename):
    directory = os.path.dirname(filename)
    os.makedirs(directory, exist_ok=True)
    with open(filename, 'w', encoding='utf-8') as f:
        json.dump(data, f, ensure_ascii=False, indent=4)
    print(f"'{filename}' 파일에 데이터가 성공적으로 저장되었습니다.")

if __name__ == "__main__":
    search_query = "파이썬"
    
    print(f"'{search_query}' 검색어로 책 목록을 가져오는 중")
    book_list = search_books_no_try_except(search_query)

    if book_list:
        json_filename = 'data/books.json'
        save_to_json_file(book_list, json_filename)
    else:
        print("검색된 책이 없거나 API 호출에 실패했습니다.")
# Out:
# '파이썬' 검색어로 책 목록을 가져오는 중 (try-except 없음)...
# 'data/books.json' 파일에 데이터가 성공적으로 저장되었습니다.

# %%
# 2. books.json 파일을 PandasDataFrame로 저장하기
import pandas as pd
import json
from IPython.display import display # display 함수를 임포트

with open('data/books.json', 'r', encoding='utf-8') as f:
    books_data = json.load(f)
    
# JSON 데이터를 Pandas DataFrame으로 변환
df = pd.DataFrame(books_data)

print("books.json 파일이 성공적으로 DataFrame으로 로드되었습니다.")

print("\n--- DataFrame의 첫 5행 ---")

# display(df.head())

print("\n--- DataFrame 정보 ---")
df.info()
# Out:
# books.json 파일이 성공적으로 DataFrame으로 로드되었습니다.
#
# --- DataFrame의 첫 5행 ---
#
# --- DataFrame 정보 ---
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        50 non-null     object
#  1   link         50 non-null     object
#  2   image        50 non-null     object
#  3   author       50 non-null     object
#  4   discount     50 non-null     object
#  5   publisher    50 non-null     object
#  6   pubdate      50 non-null     object
#  7   isbn         50 non-null     object
#  8   description  50 non-null     object
# dtypes: object(9)
# memory usage: 3.6+ KB

# %%
# 3. 검색어로 찾은 책 목록 출력하기 
from IPython.display import display 

if 'df' in locals() and not df.empty: # df가 성공적으로 로드되었고 비어있지 않은지 확인
    print("\n--- 3. 검색어로 찾은 전체 책 목록  ---")
    display(df.head(5))
else:
    print("DataFrame이 로드되지 않았거나 비어 있어 전체 목록을 출력할 수 없습니다.")
# Out:
# --- 3. 검색어로 찾은 전체 책 목록  ---
#                                                title  \
# 0  처음이야? 파이썬 기초 (동영상 강의로 배우는 292개 코드 따라하기(핵심노트+오픈...
# 1        모두의 인공지능 with 파이썬 (누구나 쉽게 시작하는 AI 기초 프로그래밍)
# 2               혼자 공부하는 파이썬 (1:1 과외하듯 배우는 프로그래밍 자습서)
# 3           Do it! 점프 투 파이썬 (중학생도 첫날부터 실습하는 초고속 입문서)
# 4                                                파이썬
#
#                                                 link  \
# 0  https://search.shopping.naver.com/book/catalog...
# 1  https://search.shopping.naver.com/book/catalog...
# 2  https://search.shopping.naver.com/book/catalog...
# 3  https://search.shopping.naver.com/book/catalog...
# 4  https://search.shopping.naver.com/book/catalog...
#
#                                                image      author discount  \
# 0  https://shopping-phinf.pstatic.net/main_550256...  윤영빈^오환^이용희    18000
# 1  https://shopping-phinf.pstatic.net/main_558136...         이영호    27000
# 2  https://shopping-phinf.pstatic.net/main_325076...         윤인성    19800
# 3  https://shopping-phinf.pstatic.net/main_403540...         박응용    19800
# 4  https://shopping-phinf.pstatic.net/main_324609...         홍의경    30400
#
#   publisher   pubdate           isbn  \
# 0      영진닷컴  20250620  9788931478006
# 1        길벗  20250725  9791140714995
# 2     한빛미디어  20220601  9791162245651
# 3   이지스퍼블리싱  20230615  9791163034735
# 4      생능출판  20220309  9788970506784
#
#                                          description
# 0  파이썬 완전 초보에게 추천합니다.\n파이썬을 처음 배우는 당신을 위한 가장 쉬운 기...
# 1  가장 쉬운 인공지능 입문서, \n생성형 AI를 반영해 한층 더 탄탄하게 돌아왔다!\...
# 2  혼자 해도 충분하다! 1:1 과외하듯 배우는 파이썬 프로그래밍 자습서\n\n『혼자 ...
# 3  프로그래밍 분야 8년 연속 베스트셀러!\n《Do it! 점프 투 파이썬》 전면 개정...
# 4  코딩 실력을 키우는 지름길은 실습이다.\n\n2008년 즈음에 검인정 중학교 교과서...

# %%
# 4. 검색어로 찾은 책 목록 중에서 가격이 2만원 이상인 책만 출력하기 
from IPython.display import display 

if 'df' in locals() and not df.empty:
    # 'discount' 컬럼을 숫자형으로 변환 (Naver API의 discount는 문자열일 수 있음)
    df['discount'] = pd.to_numeric(df['discount'], errors='coerce')
    
    # 가격이 20000원 이상인 책 필터링
    df_expensive_books = df[df['discount'] >= 20000].copy() # .copy()를 사용하여 원본 df에 영향x
    
    # 원하는 컬럼만 선택 
    columns_to_display_price = ['title', 'link', 'author', 'discount', 'publisher', 'pubdate', 'isbn']
    
    # df_expensive_books에서 해당 컬럼이 있는지 확인하고 선택
    existing_columns = [col for col in columns_to_display_price if col in df_expensive_books.columns]
    df_expensive_books = df_expensive_books[existing_columns]


    # 'discount' (가격) 기준으로 내림차순 정렬
    df_expensive_books = df_expensive_books.sort_values(by='discount', ascending=False)
    
    # 인덱스 초기화
    df_expensive_books = df_expensive_books.reset_index(drop=True)
    
    print("\n--- 4. 가격이 2만원 이상인 책 목록 ---")
    if not df_expensive_books.empty:
        # display(df_expensive_books) 대신 display(df_expensive_books.head(4))를 사용하여
        # 상위 4개 행(인덱스 0, 1, 2, 3)만 표 형태로 출력합니다.
        display(df_expensive_books.head(20))
    else:
        print("가격이 2만원 이상인 책이 없습니다.")
else:
    print("DataFrame이 로드되지 않아 필터링을 수행할 수 없습니다.")
# Out:
# --- 4. 가격이 2만원 이상인 책 목록 ---
#                                                 title  \
# 0                                        으뜸 파이썬 (개정판)
# 1                   으뜸 파이썬 (프로그래밍을 사랑하는 두 교수가 작정하고 쓴)
# 2                                                 파이썬
# 3                            파이썬 마스터 (실생활 융합 예제로 배우는)
# 4                                                 파이썬
# 5                                              독학 파이썬
# 6                                             새내기 파이썬
# 7         모두의 인공지능 with 파이썬 (누구나 쉽게 시작하는 AI 기초 프로그래밍)
# 8                                             파이썬의 정석
# 9                     내공의 파이썬 (한 권으로 끝내는 초보자용 코딩 입문서)
# 10                          파이썬의 신 (프로그래밍 언어를 배운다는 것)
# 11                     파이썬 + AI (코드조각과 실행화면으로 배우는 코딩)
# 12                                                파이썬
# 13                                       파이썬 연습 (개정판)
# 14     밑바닥부터 시작하는 딥러닝 1(리마스터판) (파이썬으로 익히는 딥러닝 이론과 구현)
# 15  혼자 공부하는 데이터 분석 with 파이썬 (1:1 과외하듯 배우는 데이터 분석 자습서)
# 16                                            파이썬 플러스
# 17                         파이썬 (다양한 예제로 알로리즘 쉽게 분석하기)
# 18                          파이썬 입문 (3step으로 확실하게 배우는)
# 19                              엑셀X파이썬 (엑셀이 파이썬을 품었다)
#
#                                                  link           author  \
# 0   https://search.shopping.naver.com/book/catalog...          박동규^강영민
# 1   https://search.shopping.naver.com/book/catalog...          박동규^강영민
# 2   https://search.shopping.naver.com/book/catalog...  Y. Daniel Liang
# 3   https://search.shopping.naver.com/book/catalog...          김종훈^김동건
# 4   https://search.shopping.naver.com/book/catalog...              홍의경
# 5   https://search.shopping.naver.com/book/catalog...         야마다 요시히로
# 6   https://search.shopping.naver.com/book/catalog...              천인국
# 7   https://search.shopping.naver.com/book/catalog...              이영호
# 8   https://search.shopping.naver.com/book/catalog...          조용주^임좌상
# 9   https://search.shopping.naver.com/book/catalog...              한선관
# 10  https://search.shopping.naver.com/book/catalog...              김주현
# 11  https://search.shopping.naver.com/book/catalog...          안용제^김남규
# 12  https://search.shopping.naver.com/book/catalog...              김영천
# 13  https://search.shopping.naver.com/book/catalog...              김기용
# 14  https://search.shopping.naver.com/book/catalog...           사이토 고키
# 15  https://search.shopping.naver.com/book/catalog...              박해선
# 16  https://search.shopping.naver.com/book/catalog...              최희식
# 17  https://search.shopping.naver.com/book/catalog...              김유진
# 18  https://search.shopping.naver.com/book/catalog...  야마다 요시히로^야마다 나미
# 19  https://search.shopping.naver.com/book/catalog...              정성일
#
#     discount publisher   pubdate           isbn
# 0      32300      생능출판  20240614  9791192932675
# 1      31680      생능출판  20200217  9788970503691
# 2      31500     에피스테메  20180302  9788920028892
# 3      31040    한빛아카데미  20250117  9791173400018
# 4      30400      생능출판  20220309  9788970506784
# 5      28800     정보문화사  20241220  9788956749891
# 6      28500      생능출판  20220630  9788970505558
# 7      27000        길벗  20250725  9791140714995
# 8      26820     길벗캠퍼스  20230110  9791140702671
# 9      24300    자유아카데미  20250315  9791158087005
# 10     24300       로드북  20161223  9788997924271
# 11     23940     디지털북스  20240715  9788960884571
# 12     23750       기한재  20200225  9788970187990
# 13     23400        그린  20220225  9788957273357
# 14     23400     한빛미디어  20250124  9791169213387
# 15     23400     한빛미디어  20230102  9791169210287
# 16     22500    인피니티북스  20240731  9791192373362
# 17     22500        다본  20190410  9791188577255
# 18     22500    시그마프레스  20210105  9791162262979
# 19     21375        길벗  20240730  9791140710195

# %%
# 6. 검색어로 찾은 책 목록 중에서 출판사가 인피니티북스인 책만 출력하기
from IPython.display import display 

if 'df' in locals() and not df.empty: 
    # 출판사가 '인피니티북스'인 책 필터링
    df_infinity_books = df[df['publisher'] == '인피니티북스'].copy() # .copy()를 사용하여 원본 df에 영향x
    
    columns_to_display_infinity = ['title', 'link', 'author', 'discount', 'publisher', 'pubdate', 'isbn']
    
    # 실제 DataFrame에 존재하는 컬럼만 선택
    existing_columns = [col for col in columns_to_display_infinity if col in df_infinity_books.columns]
    df_infinity_books = df_infinity_books[existing_columns]
    
    # 인덱스 초기화
    df_infinity_books = df_infinity_books.reset_index(drop=True)
    
    print("\n--- 6. 출판사가 '인피니티북스'인 책 목록 ---")
    if not df_infinity_books.empty:
        
        display(df_infinity_books)
    else:
        print("출판사가 '인피니티북스'인 책이 없습니다.")
else:
    print("DataFrame이 로드되지 않아 필터링을 수행할 수 없습니다.")
# Out:
# --- 6. 출판사가 '인피니티북스'인 책 목록 ---
#      title                                               link author  \
# 0      파이썬  https://search.shopping.naver.com/book/catalog...    천인국
# 1  파이썬 플러스  https://search.shopping.naver.com/book/catalog...    최희식
#
#    discount publisher   pubdate           isbn
# 0     10800    인피니티북스  20170830  9791185578330
# 1     22500    인피니티북스  20240731  9791192373362
